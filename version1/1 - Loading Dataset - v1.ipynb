# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')
RS = sum(list(map(ord, 'Dale Boca')))

import pandas as pd
pd.option_context('display.max_rows', None, 'display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

import numpy as np
import os;

# %%
import re

# %% [markdown]
# ## Lectura del Dataset

# %%
# archivo de lectura
dir_name   = '../data/original'
file_name  = 'nflx_all_tweets_raw.txt'
filename = os.path.join(dir_name, file_name)

# %%
filename
# Out:
# '../data/original/nflx_all_tweets_raw.txt'

# %%
# defino regex para extraer fecha y urls-pics
match_date = re.compile(r"(\d{4}-\d{2}-\d{2})", re.IGNORECASE)
match_url = re.compile(r"((https?|http):\/\/(www\.)?[a-z0-9\.:].*?(?=\s))", re.IGNORECASE)
match_pic = re.compile(r"pic.twitter.com/[\w].*", re.IGNORECASE)
match_arrobas  = re.compile(r'(@\w+)', re.IGNORECASE)
match_hashtags = re.compile(r"(#\w*)", re.IGNORECASE)
match_signs = re.compile(r'(&(#\d*)+;)', re.IGNORECASE)
only_words = re.compile(r'[^a-zA-Z ]', re.IGNORECASE)

# %%
with open(filename,'r') as f:

    # inicializo dataframe
    tweets = pd.DataFrame()

    # lectura del file linea por linea (en caso de que el archivo sea muy grande)
    for line in f:

        # extraigo la fecha, '' si retorna None
        date = getattr(re.search(match_date, line), 'groups', lambda:[u""])()[0]
        
        # reemplazo signo $ y '\n' por ''
        texto = line.replace('$', '')
        texto = texto.replace('\n', '')        
        
        # elimino urls, pics, hashtags y arrobas
        texto = re.sub(match_url, '', texto)
        texto = re.sub(match_pic, '', texto)
        texto = re.sub(match_arrobas, '', texto)
        texto = re.sub(match_hashtags, '', texto)
        texto = re.sub(match_signs, '', texto)
        
        # elimino los encabezados (nro de tweet, date, hora, cod y posteador)
        texto = ' '.join(texto.split(' ')[5:])
        
        # me quedo son con las palabras
        texto = re.sub(only_words, "", texto)
      
        if date != '':
            # creo diccionario para agregar a dataframe
            d = {
                'date' : date,
                'text' : texto,
            }
            tweets = tweets.append(d, ignore_index=True)

# %%
tweets.shape
# Out:
# (35983, 2)

# %%
tweets = tweets.sort_values(by='date')

# %%
tweets.head(40)
# Out:
#              date  \
# 35982  2017-11-23
# 35957  2017-11-23
# 35956  2017-11-23
# 35955  2017-11-23
# 35954  2017-11-23
# 35953  2017-11-23
# 35952  2017-11-23
# 35951  2017-11-23
# 35950  2017-11-23
# 35949  2017-11-23
# 35948  2017-11-23
# 35947  2017-11-23
# 35946  2017-11-23
# 35945  2017-11-23
# 35944  2017-11-23
# 35943  2017-11-23
# 35942  2017-11-23
# 35941  2017-11-23
# 35940  2017-11-23
# 35939  2017-11-23
# 35958  2017-11-23
# 35959  2017-11-23
# 35981  2017-11-23
# 35961  2017-11-23
# 35960  2017-11-23
# 35979  2017-11-23
# 35978  2017-11-23
# 35977  2017-11-23
# 35976  2017-11-23
# 35975  2017-11-23
# 35974  2017-11-23
# 35973  2017-11-23
# 35972  2017-11-23
# 35980  2017-11-23
# 35970  2017-11-23
# 35969  2017-11-23
# 35968  2017-11-23
# 35967  2017-11-23
# 35966  2017-11-23
# 35965  2017-11-23
#
#                                                                                                                                                                                                                                                                              text
# 35982  Scandal creator  Why I left ABC for Netflix DIS NFLX
# 35957  Netflix Inc NFLX Stock Live Analysis
# 35956  Netflix NFLX Market Valuation Rose While Parkwood Trimmed by  Million Its Holding
# 35955     Strong Price Compression from a Daily Rising Wedge   red  NFLX
# 35954  VMware  Analysts think these stocks can be a game changer Netflix Inc NASDAQ NFLX Retail        via TheCloudNetwork  on
# 35953     Emerging Stocks Inc NASDAQ NFLX Netflix NFLX NYSE RF Regions Financial Corporation RF
# 35952  The reason this has come to the forefront is socalled fast lanes Netflix and Google have traditionally paid for peering  content delivery which essentially embeds their content into the ISPs network ISPs want to charge for these fast lanes  GOOGNFLX dont want to pay
# 35951  David B Wells Sells  Shares of Netflix Inc NFLX Stock
# 35950  Advisor Group Inc Sells  Shares of Netflix Inc NFLX
# 35949  Netflix Inc NFLX Shares Bought by Soma Equity Partners LP
# 35948  Rhumbline Advisers Acquires  Shares of Netflix Inc NFLX
# 35947  Oppenheimer  Co Inc Lowers Stake in Netflix Inc NFLX
# 35946  Netflix Inc NFLX Position Lifted by Bronfman EL Rothschild LP
# 35945  Highland Private Wealth Management Acquires Shares of  Netflix Inc NFLX
# 35944  Winslow Capital Management Boosted Netflix NFLX Holding
# 35943  Sigma Planning Corp Acquires  Shares of Netflix Inc NFLX
# 35942  Netflix Inc NFLX Shares Sold by American International Group Inc
# 35941  Highland Private Wealth Management Acquires Shares of  Netflix Inc NFLX
# 35940  Heres everything leaving Netflix in September that you need to watch right now NFLX
# 35939  Netflix Inc NFLX CFO Sells  in Stock
# 35958  Steadfast Capital Management LP Has Trimmed Its Netflix NFLX Stake
# 35959  Netflix NFLX Hold Rating Reconfirmed at BMO Capital
# 35981  Scandal creator Shonda Rhimes Why I left ABC for Netflix DIS NFLX
# 35961  D L Carlson Investment Group Lowered Netflix NFLX Holding
# 35960  Netflix Inc NFLX Given Consensus Recommendation of Buy by Analysts
# 35979  Are You Bullish Or Bearish On  Start  NFLX With   XBT BTC
# 35978  Netflix Inc NFLX CEO Reed Hastings Sells  Shares
# 35977  Netflix Inc NFLX CEO Reed Hastings Sells  Shares
# 35976  Why Netflix NFLX and Amazon AMZN Outperformed on the Day that Net Neutrality Died
# 35975  Prudential Financial Inc Has  Million Stake in Netflix Inc NFLX
# 35974  Why Netflix NFLX and Amazon AMZN Outperformed on the Day that Net Neutrality Died
# 35973  American Century Companies Inc Has  Million Holdings in Netflix Inc NFLX
# 35972  Sterling Global Strategies LLC Purchases New Position in Netflix Inc NFLX
# 35980  Netflix CEO Reed Hastings Sells  in NFLX
# 35970  NFLX Why Netflix NFLX and Amazon AMZN Outperformed on the Day that Net Neutrality Died
# 35969  NFLX The Zacks Analyst Blog Highlights Apple Netflix Amazon Alphabet and Fitbit
# 35968  NFLX Netflix Rides on Subscriber Addition and Content Strength
# 35967  NFLX Top Stock Reports for BP Plc Mitsubishi UFJ  Netflix
# 35966  NFLX  Growth Stocks That Could Put Netflixs Returns to Shame
# 35965  NFLX  Stocks That Feel Like Netflix in

# %%
tweets.to_csv('nflx_all_tweets.csv')
